# %%
import numpy as np

omega_times = np.array([0.186957, 0.053229, 0.067199, 0.038250, 0.12417, 0.037649])

omega_iters = np.array([2355, 194, 131, 166, 206, 419])

print(omega_times/omega_iters)
# Out:
# [7.93872611e-05 2.74376289e-04 5.12969466e-04 2.30421687e-04
#  6.02766990e-04 8.98544153e-05]
